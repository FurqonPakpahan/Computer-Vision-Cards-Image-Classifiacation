# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\FURQON\anaconda3\envs\hacktiv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from keras.models import load_model
import numpy as np
from keras.preprocessing import image

loaded_model = load_model('model_name2.h5')

img_path = 'img/image.png'
img = image.load_img(img_path, target_size=(150, 150))  
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  

predictions = loaded_model.predict(img_array)

model_pred_final = np.where(predictions >= 0.35, 1, 0)

plt.imshow(img)
plt.title('Original Image')
plt.show()

print('Prediction is a {}'.format('king of spades' if model_pred_final[0][0] == 0 else 'queen of hearts'))
# Out:
# WARNING:tensorflow:From c:\Users\FURQON\anaconda3\envs\hacktiv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\FURQON\anaconda3\envs\hacktiv\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 1/1 [==============================] - 4s 4s/step
# Prediction is a queen of hearts

# %%
from keras.models import load_model
import numpy as np
from keras.preprocessing import image

loaded_model = load_model('model_name2.h5')

img_path = 'img/imagee.png'
img = image.load_img(img_path, target_size=(150, 150))  
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  

predictions = loaded_model.predict(img_array)

model_pred_final = np.where(predictions >= 0.35, 1, 0)

plt.imshow(img)
plt.title('Original Image')
plt.show()

print('Prediction is a {}'.format('king of spades' if model_pred_final[0][0] == 0 else 'queen of hearts'))
# Out:
# 1/1 [==============================] - 4s 4s/step
# Prediction is a king of spades
